# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Creating a new note book to explore the cookbook features

# %%
print("Hello, world")
# Out:
# Hello, world

# %%
phtml = pd.read_html("https://www.moneycontrol.com/stocks/marketstats/bsegainer/index.php")

# %%
phtml
# Out:
# [                                         Company Name        High      Low  \
#  0   NTPC Add to  Watchlist | Portfolio ACTIONS  NT...      134.10   129.85
#  1                                               5-Day   726390.20      NaN
#  2                                              10-Day   712182.70      NaN
#  3                                              30-Day   536353.00      NaN
#  4                                               3-Day      37.55%      NaN
#  5                                               5-Day      42.68%      NaN
#  6                                               8-Day      43.80%      NaN
#  7   Larsen Add to  Watchlist | Portfolio NEWS  Buy...     1414.95  1375.55
#  8                                               5-Day   403775.00      NaN
#  9                                              10-Day   370983.40      NaN
#  10                                             30-Day   244325.00      NaN
# ...

# %%
frame_bse_snp = pd.read_html("https://www.moneycontrol.com/stocks/marketstats/bsegainer/index.php")
frame_bse_snp
# Out:
# [                                         Company Name        High      Low  \
#  0   NTPC Add to  Watchlist | Portfolio ACTIONS  NT...      134.10   129.85
#  1                                               5-Day   726390.20      NaN
#  2                                              10-Day   712182.70      NaN
#  3                                              30-Day   536353.00      NaN
#  4                                               3-Day      37.55%      NaN
#  5                                               5-Day      42.68%      NaN
#  6                                               8-Day      43.80%      NaN
#  7   Larsen Add to  Watchlist | Portfolio NEWS  Buy...     1414.95  1375.55
#  8                                               5-Day   403775.00      NaN
#  9                                              10-Day   370983.40      NaN
#  10                                             30-Day   244325.00      NaN
# ...

# %%
frame_bse_snp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-5b7a1b62d398> in <module>
# ----> 1 frame_bse_snp.T
#
# AttributeError: 'list' object has no attribute 'T'

# %%
drange = pd.date_range('2013-08-01', periods=6, freq='B')
drange
# Out:
# DatetimeIndex(['2013-08-01', '2013-08-02', '2013-08-05', '2013-08-06',
#                '2013-08-07', '2013-08-08'],
#               dtype='datetime64[ns]', freq='B')

# %%
dat = np.random.randn(6, 1)
dat
# Out:
# array([[-0.8071186 ],
#        [ 1.65192201],
#        [-0.61188381],
#        [-1.12045392],
#        [-0.38013505],
#        [-0.82582471]])

# %%
df = pd.DataFrame(dat, index=drange, columns=list('A') )
df
# Out:
#                    A
# 2013-08-01 -0.807119
# 2013-08-02  1.651922
# 2013-08-05 -0.611884
# 2013-08-06 -1.120454
# 2013-08-07 -0.380135
# 2013-08-08 -0.825825

# %%
df.loc[df.index[3], 'A'] = np.nan
df
# Out:
#                    A
# 2013-08-01 -0.807119
# 2013-08-02  1.651922
# 2013-08-05 -0.611884
# 2013-08-06       NaN
# 2013-08-07 -0.380135
# 2013-08-08 -0.825825

# %%
df.reindex(df.index[::-1]).ffill()
# Out:
#                    A
# 2013-08-08 -0.825825
# 2013-08-07 -0.380135
# 2013-08-06 -0.380135
# 2013-08-05 -0.611884
# 2013-08-02  1.651922
# 2013-08-01 -0.807119

# %%
df = pd.DataFrame([[30, 20]], columns=['Apples', 'Bananas'])
df
# Out:
#    Apples  Bananas
# 0      30       20
